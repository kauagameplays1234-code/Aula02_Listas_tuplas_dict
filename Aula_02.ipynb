# %% [markdown]
# <a href="https://colab.research.google.com/github/kauagameplays1234-code/Aula02_Listas_tuplas_dict/blob/main/Aula_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Atividade 01

# %%
materias = ['matemática', 'português', 'inglês']

notas = (9.5, 9.3, 9.1 )

aluno = {
    'nome':'João',
    'idade': '25',
    'curso': 'TI'
}

print ("materias:",materias)
print ("notas:", notas)
print ("informações sobre o aluno:", aluno)
# Out:
# materias: ['matemática', 'português', 'inglês']
# notas: (9.5, 9.3, 9.1)
# informações sobre o aluno: {'nome': 'João', 'idade': '25', 'curso': 'TI'}

# %% [markdown]
# Atividade 02

# %%
acessorios = ['volante' , 'câmbio de marcha', 'retrovisores']
especificacoes = (450 , 50.00)
carro = {
    'marca' : 'audi',
    'modelo' : 'suv',
    'ano' : '2002'
}

print ("acessórios:", acessorios)
print ("cavalos/capacidade do tanque:", especificacoes)
print ("informações sobre o carro:", carro)
# Out:
# acessórios: ['volante', 'câmbio de marcha', 'retrovisores']
# cavalos/capacidade do tanque: (450, 50.0)
# informações sobre o carro: {'marca': 'audi', 'modelo': 'suv', 'ano': '2002'}
